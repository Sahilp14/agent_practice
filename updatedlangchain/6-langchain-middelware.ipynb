# %% [markdown]
# ### Middelware

# %% [markdown]
# Middelware provides a way to more tightly control what happens inside the agent. Middelware is useful for foll:
#
# - Tracking agent behaviour with logging, analytics, or debugging.
# - Transforming prompts, tool selection, and output formatting.
# - Adding retries, fallbacks and early terminations logic.
# - Applying rate limits, guradrails and PII detection.

# %%
import os
from dotenv import load_dotenv
load_dotenv()

os.environ['GOOGLE_API_KEY'] = os.getenv('GOOGLE_API_KEY')

# %% [markdown]
# ### Summarization MiddleWare

# %%
from langchain_google_genai import ChatGoogleGenerativeAI
from langchain.agents.middleware import SummarizationMiddleware
from langgraph.checkpoint.memory import InMemorySaver
from langchain.agents import create_agent
from langchain.messages import HumanMessage

# Main LLM
llm = ChatGoogleGenerativeAI(
    model="gemini-2.5-flash",
    temperature=0
)

# Middleware LLM (separate instance is best)
summary_llm = ChatGoogleGenerativeAI(
    model="gemini-2.5-flash",
    temperature=0
)

agent = create_agent(
    model=llm,
    checkpointer=InMemorySaver(),
    middleware=[
        SummarizationMiddleware(
            model=summary_llm,       
            trigger=("messages", 10),
            keep=("messages", 4)
        )
    ],
)

# %%
config = {"configurable":{"thread_id":"test-1"}}

# %%
questions = [
    "what is 2+2?",
    "what is 5*5?",
    "what is 10/2?",
    "what is 10-2?",
    "what is 5*2?",
    "what is 4*4"
]

for q in questions:
    response = agent.invoke({"messages": [HumanMessage(content=q)]}, config)
    print(f"Messages: {response['messages']}")
    print(f"Messages: {len(response['messages'])}")
# Out:
# Messages: [HumanMessage(content='Here is a summary of the conversation to date:\n\nThe user has been asking basic arithmetic questions (addition, multiplication, division) and the AI has been providing correct answers. The current pending question is "what is 10-2?".', additional_kwargs={}, response_metadata={}, id='5c9a3be7-9dd1-44ab-99dd-1415ce6e884e'), AIMessage(content='10 - 2 = 8', additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019b5652-e16c-7e12-9393-290c09e92c64-0', usage_metadata={'input_tokens': 60, 'output_tokens': 39, 'total_tokens': 99, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 31}}), HumanMessage(content='what is 5*2?', additional_kwargs={}, response_metadata={}, id='5ce19e14-abee-4a8a-8170-fe56e4dbde98'), AIMessage(content='5 * 2 = 10', additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019b5652-e632-77a2-87b8-c33a5fb1846b-0', usage_metadata={'input_tokens': 77, 'output_tokens': 36, 'total_tokens': 113, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 28}}), HumanMessage(content='what is 4*4', additional_kwargs={}, response_metadata={}, id='64c63668-7e47-4cbb-9ea8-bd8f24ff9730'), HumanMessage(content='what is 2+2?', additional_kwargs={}, response_metadata={}, id='66da7ea2-0123-4179-b87b-9dd8e7f59fd0'), AIMessage(content='4 * 4 = 16\n2 + 2 = 4', additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019b568e-caf2-7960-a1be-4281a4f064ad-0', usage_metadata={'input_tokens': 91, 'output_tokens': 136, 'total_tokens': 227, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 120}})]
# Messages: 7
# Messages: [HumanMessage(content='Here is a summary of the conversation to date:\n\nThe user has been asking basic arithmetic questions (addition, multiplication, division) and the AI has been providing correct answers. The current pending question is "what is 10-2?".', additional_kwargs={}, response_metadata={}, id='5c9a3be7-9dd1-44ab-99dd-1415ce6e884e'), AIMessage(content='10 - 2 = 8', additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019b5652-e16c-7e12-9393-290c09e92c64-0', usage_metadata={'input_tokens': 60, 'output_tokens': 39, 'total_tokens': 99, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 31}}), HumanMessage(content='what is 5*2?', additional_kwargs={}, response_metadata={}, id='5ce19e14-abee-4a8a-8170-fe56e4dbde98'), AIMessage(content='5 * 2 = 10', additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019b5652-e632-77a2-87b8-c33a5fb1846b-0', usage_metadata={'input_tokens': 77, 'output_tokens': 36, 'total_tokens': 113, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 28}}), HumanMessage(content='what is 4*4', additional_kwargs={}, response_metadata={}, id='64c63668-7e47-4cbb-9ea8-bd8f24ff9730'), HumanMessage(content='what is 2+2?', additional_kwargs={}, response_metadata={}, id='66da7ea2-0123-4179-b87b-9dd8e7f59fd0'), AIMessage(content='4 * 4 = 16\n2 + 2 = 4', additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019b568e-caf2-7960-a1be-4281a4f064ad-0', usage_metadata={'input_tokens': 91, 'output_tokens': 136, 'total_tokens': 227, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 120}}), HumanMessage(content='what is 5*5?', additional_kwargs={}, response_metadata={}, id='7ca555b8-cdde-4726-8a62-4c00079e08e9'), AIMessage(content='5 * 5 = 25', additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019b568e-d20c-70d3-a80d-e601bd2aa651-0', usage_metadata={'input_tokens': 116, 'output_tokens': 36, 'total_tokens': 152, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 28}})]
# Messages: 9
# Messages: [HumanMessage(content='Here is a summary of the conversation to date:\n\nThe user is asking basic arithmetic questions (addition, multiplication, subtraction). The AI has successfully answered previous questions. The current pending questions are "what is 4*4?" and "what is 2+2?".', additional_kwargs={}, response_metadata={}, id='d5da58f1-29fa-4d92-a7c7-eaffa4dc99d0'), AIMessage(content='4 * 4 = 16\n2 + 2 = 4', additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019b568e-caf2-7960-a1be-4281a4f064ad-0', usage_metadata={'input_tokens': 91, 'output_tokens': 136, 'total_tokens': 227, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 120}}), HumanMessage(content='what is 5*5?', additional_kwargs={}, response_metadata={}, id='7ca555b8-cdde-4726-8a62-4c00079e08e9'), AIMessage(content='5 * 5 = 25', additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019b568e-d20c-70d3-a80d-e601bd2aa651-0', usage_metadata={'input_tokens': 116, 'output_tokens': 36, 'total_tokens': 152, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 28}}), HumanMessage(content='what is 10/2?', additional_kwargs={}, response_metadata={}, id='ae769dd1-c206-4a46-812d-d1f1c968a608'), AIMessage(content='10 / 2 = 5', additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019b568e-ec52-7de3-b272-ca92f3881489-0', usage_metadata={'input_tokens': 99, 'output_tokens': 36, 'total_tokens': 135, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 28}})]
# Messages: 6
# Messages: [HumanMessage(content='Here is a summary of the conversation to date:\n\nThe user is asking basic arithmetic questions (addition, multiplication, subtraction). The AI has successfully answered previous questions. The current pending questions are "what is 4*4?" and "what is 2+2?".', additional_kwargs={}, response_metadata={}, id='d5da58f1-29fa-4d92-a7c7-eaffa4dc99d0'), AIMessage(content='4 * 4 = 16\n2 + 2 = 4', additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019b568e-caf2-7960-a1be-4281a4f064ad-0', usage_metadata={'input_tokens': 91, 'output_tokens': 136, 'total_tokens': 227, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 120}}), HumanMessage(content='what is 5*5?', additional_kwargs={}, response_metadata={}, id='7ca555b8-cdde-4726-8a62-4c00079e08e9'), AIMessage(content='5 * 5 = 25', additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019b568e-d20c-70d3-a80d-e601bd2aa651-0', usage_metadata={'input_tokens': 116, 'output_tokens': 36, 'total_tokens': 152, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 28}}), HumanMessage(content='what is 10/2?', additional_kwargs={}, response_metadata={}, id='ae769dd1-c206-4a46-812d-d1f1c968a608'), AIMessage(content='10 / 2 = 5', additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019b568e-ec52-7de3-b272-ca92f3881489-0', usage_metadata={'input_tokens': 99, 'output_tokens': 36, 'total_tokens': 135, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 28}}), HumanMessage(content='what is 10-2?', additional_kwargs={}, response_metadata={}, id='52d3b260-be6b-4122-b2fa-756ad649e8f1'), AIMessage(content='10 - 2 = 8', additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019b568e-f0fd-74e3-9e72-6413f93a70cc-0', usage_metadata={'input_tokens': 117, 'output_tokens': 32, 'total_tokens': 149, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 24}})]
# Messages: 8
# Messages: [HumanMessage(content='Here is a summary of the conversation to date:\n\nThe user is asking basic arithmetic questions (addition, multiplication, subtraction). The AI has successfully answered previous questions. The current pending questions are "what is 4*4?" and "what is 2+2?".', additional_kwargs={}, response_metadata={}, id='d5da58f1-29fa-4d92-a7c7-eaffa4dc99d0'), AIMessage(content='4 * 4 = 16\n2 + 2 = 4', additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019b568e-caf2-7960-a1be-4281a4f064ad-0', usage_metadata={'input_tokens': 91, 'output_tokens': 136, 'total_tokens': 227, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 120}}), HumanMessage(content='what is 5*5?', additional_kwargs={}, response_metadata={}, id='7ca555b8-cdde-4726-8a62-4c00079e08e9'), AIMessage(content='5 * 5 = 25', additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019b568e-d20c-70d3-a80d-e601bd2aa651-0', usage_metadata={'input_tokens': 116, 'output_tokens': 36, 'total_tokens': 152, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 28}}), HumanMessage(content='what is 10/2?', additional_kwargs={}, response_metadata={}, id='ae769dd1-c206-4a46-812d-d1f1c968a608'), AIMessage(content='10 / 2 = 5', additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019b568e-ec52-7de3-b272-ca92f3881489-0', usage_metadata={'input_tokens': 99, 'output_tokens': 36, 'total_tokens': 135, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 28}}), HumanMessage(content='what is 10-2?', additional_kwargs={}, response_metadata={}, id='52d3b260-be6b-4122-b2fa-756ad649e8f1'), AIMessage(content='10 - 2 = 8', additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019b568e-f0fd-74e3-9e72-6413f93a70cc-0', usage_metadata={'input_tokens': 117, 'output_tokens': 32, 'total_tokens': 149, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 24}}), HumanMessage(content='what is 5*2?', additional_kwargs={}, response_metadata={}, id='d185fc1b-d913-410a-9123-73540217ad7b'), AIMessage(content='5 * 2 = 10', additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019b568e-f542-7863-adc2-d40896e18bd6-0', usage_metadata={'input_tokens': 134, 'output_tokens': 35, 'total_tokens': 169, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 27}})]
# Messages: 10
# Messages: [HumanMessage(content="Here is a summary of the conversation to date:\n\nError generating summary: Error calling model 'gemini-2.5-flash' (RESOURCE_EXHAUSTED): 429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/usage?tab=rate-limit. \\n* Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 5, model: gemini-2.5-flash\\nPlease retry in 53.77807866s.', 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Learn more about Gemini API quotas', 'url': 'https://ai.google.dev/gemini-api/docs/rate-limits'}]}, {'@type': 'type.googleapis.com/google.rpc.QuotaFailure', 'violations': [{'quotaMetric': 'generativelanguage.googleapis.com/generate_content_free_tier_requests', 'quotaId': 'GenerateRequestsPerMinutePerProjectPerModel-FreeTier', 'quotaDimensions': {'location': 'global', 'model': 'gemini-2.5-flash'}, 'quotaValue': '5'}]}, {'@type': 'type.googleapis.com/google.rpc.RetryInfo', 'retryDelay': '53s'}]}}", additional_kwargs={}, response_metadata={}, id='1a983600-5131-48db-a6f2-7f03774ac3ee'), AIMessage(content='10 - 2 = 8', additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019b568e-f0fd-74e3-9e72-6413f93a70cc-0', usage_metadata={'input_tokens': 117, 'output_tokens': 32, 'total_tokens': 149, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 24}}), HumanMessage(content='what is 5*2?', additional_kwargs={}, response_metadata={}, id='d185fc1b-d913-410a-9123-73540217ad7b'), AIMessage(content='5 * 2 = 10', additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019b568e-f542-7863-adc2-d40896e18bd6-0', usage_metadata={'input_tokens': 134, 'output_tokens': 35, 'total_tokens': 169, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 27}}), HumanMessage(content='what is 4*4', additional_kwargs={}, response_metadata={}, id='309abe4f-f534-4beb-8e11-109bf6481bba'), AIMessage(content='4 * 4 = 16', additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019b568f-87c5-7e23-9962-94d5d12b526f-0', usage_metadata={'input_tokens': 414, 'output_tokens': 32, 'total_tokens': 446, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 24}})]
# Messages: 6

# %% [markdown]
# ### Token Size

# %%
from langgraph.types import Checkpointer
from langchain.agents import create_agent
from langchain.agents.middleware import SummarizationMiddleware
from langchain_core.tools import tool
from langchain_core.messages import HumanMessage
from langgraph.checkpoint.memory import InMemorySaver

@tool
def search_hotels(city: str) -> str:
    """search hotels - return long response to use more tokens"""
    return f"""Found hotels in {city}
    1. Grand Hotel - 5 star, $350/night, spa, pool, gym
    2. City Inn - 4 star, $250/night, business center
    3. Budget Stay - 3 star, $150/night, free wifi"""

llm = ChatGoogleGenerativeAI(
    model="gemini-2.5-flash",
    temperature=0
)

# Middleware LLM (separate instance is best)
summary_llm = ChatGoogleGenerativeAI(
    model="gemini-2.5-flash",
    temperature=0
)

agent = create_agent(
    model=llm,
    tools=[search_hotels],
    checkpointer=InMemorySaver(),
    middleware=[
        SummarizationMiddleware(
            model=summary_llm,
            trigger=("tokens",550),
            keep=("tokens",200)
        )
    ],
) 
config = {"configurable": {"thread_id": "test-1"}}

# token counter
def count_tokens(messages):
    total_chars = sum(len(str(m.content))for m in messages)
    return total_chars // 4  # 4 chars = 1 token

# %%
cities = ['Paris',"London", "New York", "Tokyo", "Sydney"]

for city in cities:
    response = agent.invoke(
        {"messages": [HumanMessage(content=f"Find hotels in {city}")]},
        config=config
    )
    tokens = count_tokens(response['messages'])
    print(f"{city}: {tokens} tokens, {len(response['messages'])} messages")
    print(f"{(response['messages'])}")
# Out:
# Paris: 104 tokens, 4 messages
# [HumanMessage(content='Find hotels in Paris', additional_kwargs={}, response_metadata={}, id='83d9bc4c-7efa-40f2-b678-33880f6cf837'), AIMessage(content='', additional_kwargs={'function_call': {'name': 'search_hotels', 'arguments': '{"city": "Paris"}'}, '__gemini_function_call_thought_signatures__': {'184af65e-029e-4961-91b4-f09d2c2647e9': ''}}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019b5965-fdae-7d90-8949-c84077f10bc7-0', tool_calls=[{'name': 'search_hotels', 'args': {'city': 'Paris'}, 'id': '184af65e-029e-4961-91b4-f09d2c2647e9', 'type': 'tool_call'}], usage_metadata={'input_tokens': 47, 'output_tokens': 68, 'total_tokens': 115, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 53}}), ToolMessage(content='Found hotels in Paris\n    1. Grand Hotel - 5 star, $350/night, spa, pool, gym\n    2. City Inn - 4 star, $250/night, business center\n    3. Budget Stay - 3 star, $150/night, free wifi', name='search_hotels', id='25513a2b-5c04-4260-8fab-9f4d75040b78', tool_call_id='184af65e-029e-4961-91b4-f09d2c2647e9'), AIMessage(content='I found a few hotels in Paris:\n\n*   **Grand Hotel**: 5-star, $350/night, with spa, pool, and gym.\n*   **City Inn**: 4-star, $250/night, with a business center.\n*   **Budget Stay**: 3-star, $150/night, with free Wi-Fi.', additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019b5966-03fd-79a0-8512-57f0e09f5ac1-0', usage_metadata={'input_tokens': 146, 'output_tokens': 84, 'total_tokens': 230, 'input_token_details': {'cache_read': 0}})]
# London: 210 tokens, 8 messages
# [HumanMessage(content='Find hotels in Paris', additional_kwargs={}, response_metadata={}, id='83d9bc4c-7efa-40f2-b678-33880f6cf837'), AIMessage(content='', additional_kwargs={'function_call': {'name': 'search_hotels', 'arguments': '{"city": "Paris"}'}, '__gemini_function_call_thought_signatures__': {'184af65e-029e-4961-91b4-f09d2c2647e9': ''}}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019b5965-fdae-7d90-8949-c84077f10bc7-0', tool_calls=[{'name': 'search_hotels', 'args': {'city': 'Paris'}, 'id': '184af65e-029e-4961-91b4-f09d2c2647e9', 'type': 'tool_call'}], usage_metadata={'input_tokens': 47, 'output_tokens': 68, 'total_tokens': 115, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 53}}), ToolMessage(content='Found hotels in Paris\n    1. Grand Hotel - 5 star, $350/night, spa, pool, gym\n    2. City Inn - 4 star, $250/night, business center\n    3. Budget Stay - 3 star, $150/night, free wifi', name='search_hotels', id='25513a2b-5c04-4260-8fab-9f4d75040b78', tool_call_id='184af65e-029e-4961-91b4-f09d2c2647e9'), AIMessage(content='I found a few hotels in Paris:\n\n*   **Grand Hotel**: 5-star, $350/night, with spa, pool, and gym.\n*   **City Inn**: 4-star, $250/night, with a business center.\n*   **Budget Stay**: 3-star, $150/night, with free Wi-Fi.', additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019b5966-03fd-79a0-8512-57f0e09f5ac1-0', usage_metadata={'input_tokens': 146, 'output_tokens': 84, 'total_tokens': 230, 'input_token_details': {'cache_read': 0}}), HumanMessage(content='Find hotels in London', additional_kwargs={}, response_metadata={}, id='6eaf9963-dad1-4900-bdc6-df801460e6b5'), AIMessage(content='', additional_kwargs={'function_call': {'name': 'search_hotels', 'arguments': '{"city": "London"}'}, '__gemini_function_call_thought_signatures__': {'1246c215-4d1f-442c-b0ab-af977c91ee20': ''}}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019b5966-09c4-7842-896c-45a6ba44479d-0', tool_calls=[{'name': 'search_hotels', 'args': {'city': 'London'}, 'id': '1246c215-4d1f-442c-b0ab-af977c91ee20', 'type': 'tool_call'}], usage_metadata={'input_tokens': 236, 'output_tokens': 57, 'total_tokens': 293, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 42}}), ToolMessage(content='Found hotels in London\n    1. Grand Hotel - 5 star, $350/night, spa, pool, gym\n    2. City Inn - 4 star, $250/night, business center\n    3. Budget Stay - 3 star, $150/night, free wifi', name='search_hotels', id='6b6cdb8b-2527-42dd-bdf3-0ef8314eab0f', tool_call_id='1246c215-4d1f-442c-b0ab-af977c91ee20'), AIMessage(content='I found a few hotels in London:\n\n*   **Grand Hotel**: 5-star, $350/night, with spa, pool, and gym.\n*   **City Inn**: 4-star, $250/night, with a business center.\n*   **Budget Stay**: 3-star, $150/night, with free Wi-Fi.', additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019b5966-0f0d-7592-9793-86b7381be274-0', usage_metadata={'input_tokens': 33 ...
# ---------------------------------------------------------------------------
# ClientError                               Traceback (most recent call last)
# File d:\Generative AI\langchainupdated\.venv\Lib\site-packages\langchain_google_genai\chat_models.py:3040, in ChatGoogleGenerativeAI._generate(self, messages, stop, run_manager, tools, functions, safety_settings, tool_config, generation_config, cached_content, tool_choice, **kwargs)
#    3039 try:
# -> 3040     response: GenerateContentResponse = self.client.models.generate_content(
#    3041         **request,
#    3042     )
#    3043 except ClientError as e:
#
# File d:\Generative AI\langchainupdated\.venv\Lib\site-packages\google\genai\models.py:5188, in Models.generate_content(self, model, contents, config)
#    5181     logger.warning(
#    5182         'Tools at indices [%s] are not compatible with automatic function '
#    5183         'calling (AFC). AFC is disabled. If AFC is intended, please '
#    (...)   5186         indices_str,
#    5187     )
# -> 5188   return self._generate_content(
#    5189       model=model, contents=contents, config=parsed_config
#    5190   )
#    5192 remaining_remote_calls_afc = _extra_utils.get_max_remote_calls_afc(
#    5193     parsed_config
#    5194 )
#
# File d:\Generative AI\langchainupdated\.venv\Lib\site-packages\google\genai\models.py:3985, in Models._generate_content(self, model, contents, config)
#    3983 request_dict = _common.encode_unserializable_types(request_dict)
# -> 3985 response = self._api_client.request(
#    3986     'post', path, request_dict, http_options
#    3987 )
#    3989 if config is not None and getattr(
#    3990     config, 'should_return_http_response', None
#    3991 ):
#
# File d:\Generative AI\langchainupdated\.venv\Lib\site-packages\google\genai\_api_client.py:1388, in BaseApiClient.request(self, http_method, path, request_dict, http_options)
#    1385 http_request = self._build_request(
#    1386     http_method, path, request_dict, http_options
#    1387 )
# -> 1388 response = self._request(http_request, http_options, stream=False)
#    1389 response_body = (
#    1390     response.response_stream[0] if response.response_stream else ''
#    1391 )
#
# File d:\Generative AI\langchainupdated\.venv\Lib\site-packages\google\genai\_api_client.py:1222, in BaseApiClient._request(self, http_request, http_options, stream)
#    1221     retry = tenacity.Retrying(**retry_kwargs)
# -> 1222     return retry(self._request_once, http_request, stream)  # type: ignore[no-any-return]
#    1224 return self._retry(self._request_once, http_request, stream)
#
# File d:\Generative AI\langchainupdated\.venv\Lib\site-packages\tenacity\__init__.py:477, in Retrying.__call__(self, fn, *args, **kwargs)
#     476 while True:
# --> 477     do = self.iter(retry_state=retry_state)
#     478     if isinstance(do, DoAttempt):
#
# File d:\Generative AI\langchainupdated\.venv\Lib\site-packages\tenacity\__init__.py:378, in BaseRetrying.iter(self, retry_state)
#     377 for action in self.iter_state.actions:
# --> 378     result = action(retry_state)
#     379 return result
#
# File d:\Generative AI\langchainupdated\.venv\Lib\site-packages\tenacity\__init__.py:420, in BaseRetrying._post_stop_check_actions.<locals>.exc_check(rs)
#     419 if self.reraise:
# --> 420     raise retry_exc.reraise()
#     421 raise retry_exc from fut.exception()
#
# File d:\Generative AI\langchainupdated\.venv\Lib\site-packages\tenacity\__init__.py:187, in RetryError.reraise(self)
#     186 if self.last_attempt.failed:
# --> 187     raise self.last_attempt.result()
#     188 raise self
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\concurrent\futures\_base.py:449, in Future.result(self, timeout)
#     448 elif self._state == FINISHED:
# --> 449     return self.__get_result()
#     451 self._condition.wait(timeout)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\concurrent\futures\_base.py:401, in Future.__get_result(self)
#     400 try:
# --> 401     raise self._exception
#     402 finally:
#     403     # Break a reference cycle with the exception in self._exception
#
# File d:\Generative AI\langchainupdated\.venv\Lib\site-packages\tenacity\__init__.py:480, in Retrying.__call__(self, fn, *args, **kwargs)
#     479 try:
# --> 480     result = fn(*args, **kwargs)
#     481 except BaseException:  # noqa: B902
#
# File d:\Generative AI\langchainupdated\.venv\Lib\site-packages\google\genai\_api_client.py:1201, in BaseApiClient._request_once(self, http_request, stream)
#    1194 response = self._httpx_client.request(
#    1195     method=http_request.method,
#    1196     url=http_request.url,
#    (...)   1199     timeout=http_request.timeout,
#    1200 )
# -> 1201 errors.APIError.raise_for_response(response)
#    1202 return HttpResponse(
#    1203     response.headers, response if stream else [response.text]
#    1204 )
#
# File d:\Generative AI\langchainupdated\.venv\Lib\site-packages\google\genai\errors.py:121, in APIError.raise_for_response(cls, response)
#     119   response_json = response.body_segments[0].get('error', {})
# --> 121 cls.raise_error(response.status_code, response_json, response)
#
# File d:\Generative AI\langchainupdated\.venv\Lib\site-packages\google\genai\errors.py:146, in APIError.raise_error(cls, status_code, response_json, response)
#     145 if 400 <= status_code < 500:
# --> 146   raise ClientError(status_code, response_json, response)
#     147 elif 500 <= status_code < 600:
#
# ClientError: 429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/usage?tab=rate-limit. \n* Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 5, model: gemini-2.5-flash\nPlease retry in 40.097216435s.', 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Learn more about Gemini API quotas', 'url': 'https://ai.google.dev/gemini-api/docs/rate-limits'}]}, {'@type': 'type.googleapis.com/google.rpc.QuotaFailure', 'violations': [{'quotaMetric': 'generativelanguage.googleapis.com/generate_content_free_tier_requests', 'quotaId': 'GenerateRequestsPerMinutePerProjectPerModel-FreeTier', 'quotaDimensions': {'location': 'global', 'model': 'gemini-2.5-flash'}, 'quotaValue': '5'}]}, {'@type': 'type.googleapis.com/google.rpc.RetryInfo', 'retryDelay': '40s'}]}}
#
# The above exception was the direct cause of the following exception:
#
# ChatGoogleGenerativeAIError               Traceback (most recent call last)
# Cell In[10], line 4
#       1 cities = ['Paris',"London", "New York", "Tokyo", "Sydney"]
#       3 for city in cities:
# ----> 4     response = agent.invoke(
#       5         {"messages": [HumanMessage(content=f"Find hotels in {city}")]},
#       6         config=config
#       7     )
#       8     tokens = count_tokens(response['messages'])
#       9     print(f"{city}: {tokens} tokens, {len(response['messages'])} messages")
#
# File d:\Generative AI\langchainupdated\.venv\Lib\site-packages\langgraph\pregel\main.py:3068, in Pregel.invoke(self, input, config, context, stream_mode, print_mode, output_keys, interrupt_before, interrupt_after, durability, **kwargs)
#    3065 chunks: list[dict[str, Any] | Any] = []
#    3066 interrupts: list[Interrupt] = []
# -> 3068 for chunk in self.stream(
#    3069     input,
#    3070     config,
#    3071     context=context,
#    3072     stream_mode=["updates", "values"]
#    3073     if stream_mode == "values"
#    3074     else stream_mode,
#    3075     print_mode=print_mode,
#    3076     output_keys=output_keys,
#    3077     interrupt_before=interrupt_before,
#    3078     interrupt_after=interrupt_after,
#    3079     durability=durability,
#    3080     **kwargs,
#    3081 ):
#    3082     if stream_mode == "values":
#    3083         if len(chunk) == 2:
#
# File d:\Generative AI\langchainupdated\.venv\Lib\site-packages\langgraph\pregel\main.py:2643, in Pregel.stream(self, input, config, context, stream_mode, print_mode, output_keys, interrupt_before, interrupt_after, durability, subgraphs, debug, **kwargs)
#    2641 for task in loop.match_cached_writes():
#    2642     loop.output_writes(task.id, task.writes, cached=True)
# -> 2643 for _ in runner.tick(
#    2644     [t for t in loop.tasks.values() if not t.writes],
#    2645     timeout=self.step_timeout,
#    2646     get_waiter=get_waiter,
#    2647     schedule_task=loop.accept_push,
#    2648 ):
#    2649     # emit output
#    2650     yield from _output(
#    2651         stream_mode, print_mode, subgraphs, stream.get, queue.Empty
#    2652     )
#    2653 loop.after_tick()
#
# File d:\Generative AI\langchainupdated\.venv\Lib\site-packages\langgraph\pregel\_runner.py:167, in PregelRunner.tick(self, tasks, reraise, timeout, retry_policy, get_waiter, schedule_task)
#     165 t = tasks[0]
#     166 try:
# --> 167     run_with_retry(
#     168         t,
#     169         retry_policy,
#     170         configurable={
#     171             CONFIG_KEY_CALL: partial(
#     172                 _call,
#     173                 weakref.ref(t),
#     174                 retry_policy=retry_policy,
#     175                 futures=weakref.ref(futures),
#     176                 schedule_task=schedule_task,
#     177                 submit=self.submit,
#     178             ),
#     179         },
#     180     )
#     181     self.commit(t, None)
#     182 except Exception as exc:
#
# File d:\Generative AI\langchainupdated\.venv\Lib\site-packages\langgraph\pregel\_retry.py:42, in run_with_retry(task, retry_policy, configurable)
#      40     task.writes.clear()
#      41     # run the task
# ---> 42     return task.proc.invoke(task.input, config)
#      43 except ParentCommand as exc:
#      44     ns: str = config[CONF][CONFIG_KEY_CHECKPOINT_NS]
#
# File d:\Generative AI\langchainupdated\.venv\Lib\site-packages\langgraph\_internal\_runnable.py:656, in RunnableSeq.invoke(self, input, config, **kwargs)
#     654     # run in context
#     655     with set_config_context(config, run) as context:
# --> 656         input = context.run(step.invoke, input, config, **kwargs)
#     657 else:
#     658     input = step.invoke(input, config)
#
# File d:\Generative AI\langchainupdated\.venv\Lib\site-packages\langgraph\_internal\_runnable.py:400, in RunnableCallable.invoke(self, input, config, **kwargs)
#     398         run_manager.on_chain_end(ret)
#     399 else:
# --> 400     ret = self.func(*args, **kwargs)
#     401 if self.recurse and isinstance(ret, Runnable):
#     402     return ret.invoke(input, config)
#
# File d:\Generative AI\langchainupdated\.venv\Lib\site-packages\langchain\agents\factory.py:1131, in create_agent.<locals>.model_node(state, runtime)
#    1118 request = ModelRequest(
#    1119     model=model,
#    1120     tools=default_tools,
#    (...)   1126     runtime=runtime,
#    1127 )
#    1129 if wrap_model_call_handler is None:
#    1130     # No handlers - execute directly
# -> 1131     response = _execute_model_sync(request)
#    1132 else:
#    1133     # Call composed handler with base handler
#    1134     response = wrap_model_call_handler(request, _execute_model_sync)
#
# File d:\Generative AI\langchainupdated\.venv\Lib\site-packages\langchain\agents\factory.py:1102, in create_agent.<locals>._execute_model_sync(request)
#    1099 if request.system_message:
#    1100     messages = [request.system_message, *messages]
# -> 1102 output = model_.invoke(messages)
#    1103 if name:
#    1104     output.name = name
#
# File d:\Generative AI\langchainupdated\.venv\Lib\site-packages\langchain_core\runnables\base.py:5557, in RunnableBindingBase.invoke(self, input, config, **kwargs)
#    5550 @override
#    5551 def invoke(
#    5552     self,
#    (...)   5555     **kwargs: Any | None,
#    5556 ) -> Output:
# -> 5557     return self.bound.invoke(
#    5558         input,
#    5559         self._merge_configs(config),
#    5560         **{**self.kwargs, **kwargs},
#    5561     )
#
# File d:\Generative AI\langchainupdated\.venv\Lib\site-packages\langchain_google_genai\chat_models.py:2529, in ChatGoogleGenerativeAI.invoke(self, input, config, code_execution, stop, **kwargs)
#    2526         msg = "Tools are already defined.code_execution tool can't be defined"
#    2527         raise ValueError(msg)
# -> 2529 return super().invoke(input, config, stop=stop, **kwargs)
#
# File d:\Generative AI\langchainupdated\.venv\Lib\site-packages\langchain_core\language_models\chat_models.py:398, in BaseChatModel.invoke(self, input, config, stop, **kwargs)
#     384 @override
#     385 def invoke(
#     386     self,
#    (...)    391     **kwargs: Any,
#     392 ) -> AIMessage:
#     393     config = ensure_config(config)
#     394     return cast(
#     395         "AIMessage",
#     396         cast(
#     397             "ChatGeneration",
# --> 398             self.generate_prompt(
#     399                 [self._convert_input(input)],
#     400                 stop=stop,
#     401                 callbacks=config.get("callbacks"),
#     402                 tags=config.get("tags"),
#     403                 metadata=config.get("metadata"),
#     404                 run_name=config.get("run_name"),
#     405                 run_id=config.pop("run_id", None),
#     406                 **kwargs,
#     407             ).generations[0][0],
#     408         ).message,
#     409     )
#
# File d:\Generative AI\langchainupdated\.venv\Lib\site-packages\langchain_core\language_models\chat_models.py:1117, in BaseChatModel.generate_prompt(self, prompts, stop, callbacks, **kwargs)
#    1108 @override
#    1109 def generate_prompt(
#    1110     self,
#    (...)   1114     **kwargs: Any,
#    1115 ) -> LLMResult:
#    1116     prompt_messages = [p.to_messages() for p in prompts]
# -> 1117     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#
# File d:\Generative AI\langchainupdated\.venv\Lib\site-packages\langchain_core\language_models\chat_models.py:927, in BaseChatModel.generate(self, messages, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#     924 for i, m in enumerate(input_messages):
#     925     try:
#     926         results.append(
# --> 927             self._generate_with_cache(
#     928                 m,
#     929                 stop=stop,
#     930                 run_manager=run_managers[i] if run_managers else None,
#     931                 **kwargs,
#     932             )
#     933         )
#     934     except BaseException as e:
#     935         if run_managers:
#
# File d:\Generative AI\langchainupdated\.venv\Lib\site-packages\langchain_core\language_models\chat_models.py:1221, in BaseChatModel._generate_with_cache(self, messages, stop, run_manager, **kwargs)
#    1219     result = generate_from_stream(iter(chunks))
#    1220 elif inspect.signature(self._generate).parameters.get("run_manager"):
# -> 1221     result = self._generate(
#    1222         messages, stop=stop, run_manager=run_manager, **kwargs
#    1223     )
#    1224 else:
#    1225     result = self._generate(messages, stop=stop, **kwargs)
#
# File d:\Generative AI\langchainupdated\.venv\Lib\site-packages\langchain_google_genai\chat_models.py:3044, in ChatGoogleGenerativeAI._generate(self, messages, stop, run_manager, tools, functions, safety_settings, tool_config, generation_config, cached_content, tool_choice, **kwargs)
#    3040     response: GenerateContentResponse = self.client.models.generate_content(
#    3041         **request,
#    3042     )
#    3043 except ClientError as e:
# -> 3044     _handle_client_error(e, request)
#    3046 return _response_to_result(response)
#
# File d:\Generative AI\langchainupdated\.venv\Lib\site-packages\langchain_google_genai\chat_models.py:145, in _handle_client_error(e, request)
#     143 model_name = request.get("model", "unknown")
#     144 msg = f"Error calling model '{model_name}' ({e.status}): {e}"
# --> 145 raise ChatGoogleGenerativeAIError(msg) from e
#
# ChatGoogleGenerativeAIError: Error calling model 'gemini-2.5-flash' (RESOURCE_EXHAUSTED): 429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/usage?tab=rate-limit. \n* Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 5, model: gemini-2.5-flash\nPlease retry in 40.097216435s.', 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Learn more about Gemini API quotas', 'url': 'https://ai.google.dev/gemini-api/docs/rate-limits'}]}, {'@type': 'type.googleapis.com/google.rpc.QuotaFailure', 'violations': [{'quotaMetric': 'generativelanguage.googleapis.com/generate_content_free_tier_requests', 'quotaId': 'GenerateRequestsPerMinutePerProjectPerModel-FreeTier', 'quotaDimensions': {'location': 'global', 'model': 'gemini-2.5-flash'}, 'quotaValue': '5'}]}, {'@type': 'type.googleapis.com/google.rpc.RetryInfo', 'retryDelay': '40s'}]}}
# During task with name 'model' and id 'ed83339e-cdfc-186d-b49b-06df8b9530d5'

# %% [markdown]
# ### Fraction

# %%
from langgraph.types import Checkpointer
from langchain.agents import create_agent
from langchain.agents.middleware import SummarizationMiddleware
from langchain_core.tools import tool
from langchain_core.messages import HumanMessage
from langgraph.checkpoint.memory import InMemorySaver
from langchain_google_genai import ChatGoogleGenerativeAI


@tool
def search_hotels(city: str) -> str:
    """search hotels - return long response to use more tokens"""
    return f"""Found hotels in {city}
    1. Grand Hotel - 5 star, $350/night, spa, pool, gym"""

llm = ChatGoogleGenerativeAI(
    model="gemini-2.5-flash",
    temperature=0
)

# Middleware LLM (separate instance is best)
summary_llm = ChatGoogleGenerativeAI(
    model="gemini-2.5-flash",
    temperature=0
)

# Low fraction for testing
agent = create_agent(
    model=llm,
    tools=[search_hotels],
    checkpointer=InMemorySaver(),
    middleware=[
        SummarizationMiddleware(
            model=summary_llm,
            trigger=("fraction",0.002),  # 0.5% == 640 tokens
            keep=("fraction",0.001)      # 0.2% == 256 tokens
        )
    ],
) 
config = {"configurable": {"thread_id": "test-1"}}

# token counter
def count_tokens(messages):
    return sum(len(str(m.content))for m in messages) // 4  # 4 chars = 1 token

# Test

cities = ['Paris',"London", "New York", "Tokyo", "Sydney"]

for city in cities:
    response = agent.invoke(
        {"messages": [HumanMessage(content=f"Find hotels in {city}")]},
        config=config
    )
    tokens = count_tokens(response['messages'])
    fraction = tokens / 128000
    print(f"{city}: {tokens} tokens, {len(response['messages'])} messages")
    print(f"{(response['messages'])}")
# Out:
# Paris: 57 tokens, 4 messages
# [HumanMessage(content='Find hotels in Paris', additional_kwargs={}, response_metadata={}, id='7962e06b-725f-4611-a208-857ed7034153'), AIMessage(content='', additional_kwargs={'function_call': {'name': 'search_hotels', 'arguments': '{"city": "Paris"}'}, '__gemini_function_call_thought_signatures__': {'dd4395a1-4541-4cb7-ba0b-66c42fd03da5': '...'}}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019b59f4-462c-71d2-b7ea-d665300fd6c6-0', tool_calls=[{'name': 'search_hotels', 'args': {'city': 'Paris'}, 'id': 'dd4395a1-4541-4cb7-ba0b-66c42fd03da5', 'type': 'tool_call'}], usage_metadata={'input_tokens': 47, 'output_tokens': 104, 'total_tokens': 151, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 89}}), ToolMessage(content='Found hotels in Paris\n    1. Grand Hotel - 5 star, $350/night, spa, pool, gym', name='search_hotels', id='0a8cea1b-4635-4769-b996-ff7d2313fdc8', tool_call_id='dd4395a1-4541-4cb7-ba0b-66c42fd03da5'), AIMessage(content='I found several hotels in Paris, including the Grand Hotel, which is a 5-star hotel, costs $350/night, and has a spa, pool, and gym.', additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019b59f4-4f44-7561-8b13-96dc7a81e7bd-0', usage_metadata={'input_tokens': 104, 'output_tokens': 39, 'total_tokens': 143, 'input_token_details': {'cache_read': 0}})]
# London: 115 tokens, 8 messages
# [HumanMessage(content='Find hotels in Paris', additional_kwargs={}, response_metadata={}, id='7962e06b-725f-4611-a208-857ed7034153'), AIMessage(content='', additional_kwargs={'function_call': {'name': 'search_hotels', 'arguments': '{"city": "Paris"}'}, '__gemini_function_call_thought_signatures__': {'dd4395a1-4541-4cb7-ba0b-66c42fd03da5': '...'}}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019b59f4-462c-71d2-b7ea-d665300fd6c6-0', tool_calls=[{'name': 'search_hotels', 'args': {'city': 'Paris'}, 'id': 'dd4395a1-4541-4cb7-ba0b-66c42fd03da5', 'type': 'tool_call'}], usage_metadata={'input_tokens': 47, 'output_tokens': 104, 'total_tokens': 151, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 89}}), ToolMessage(content='Found hotels in Paris\n    1. Grand Hotel - 5 star, $350/night, spa, pool, gym', name='search_hotels', id='0a8cea1b-4635-4769-b996-ff7d2313fdc8', tool_call_id='dd4395a1-4541-4cb7-ba0b-66c42fd03da5'), AIMessage(content='I found several hotels in Paris, including the Grand Hotel, which is a 5-star hotel, costs $350/night, and has a spa, pool, and gym.', additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019b59f4-4f44-7561-8b13-96dc7a81e7bd-0', usage_metadata={'input_tokens': 104, 'output_tokens': 39, 'total_tokens': 143, 'input_token_details': {'cache_read': 0}}), HumanMessage(content='Find hotels in London', additional_kwargs={}, response_metadata={}, id='63d1b57b-5526-4a1f-b8dd-3e6c1e773107'), AIMessage(content='', additional_kwargs={'function_call': {'name': 'search_hotels', 'arguments': '{"city": "London"}'}, '__gemini_function_call_thought_signatures__': {'de9a88dc-dedb-4b38-a16a-17f673a53126': ''}}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019b59f4-5536-70b0-a22f-64fda11c83ea-0', tool_calls=[{'name': 'search_hotels', 'args': {'city': 'London'}, 'id': 'de9a88dc-dedb-4b38-a16a-17f673a53126', 'type': 'tool_call'}], usage_metadata={'input_tokens': 149, 'output_tokens': 57, 'total_tokens': 206, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 42}}), ToolMessage(content='Found hotels in London\n    1. Grand Hotel - 5 star, $350/night, spa, pool, gym', name='search_hotels', id='93ee53c5-bd9b-4917-a112-671c6dcd106c', tool_call_id='de9a88dc-dedb-4b38-a16a-17f673a53126'), AIMessage(content='I found several hotels in London, including the Grand Hotel, which is a 5-star hotel, costs $350/night, and has a spa, pool, and gym.', additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019b59f4-5c66-7410-9604-f2f737345893-0', usage_metadata={'input_tokens': 206, 'output_tokens': 39, 'total_tokens': 245, 'input_token_details': {'cache_read': 0}})]
# New York: 174 tokens, 12 messages
# [HumanMessage(content='Find hotels in Paris', additional_kwargs={}, response_metadata={}, id='7962e06b-725f-4611-a208-857ed7034153'), AIMessage(content='', additional_kwargs={'function_call': {'name': 'search_hotels', 'arguments': '{"city": "Paris"}'}, '__gemini_function_call_thought_signatures__': {'dd4395a1-4541-4cb7-ba0b-66c42fd03da5': '...'}}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019b59f4-462c-71d2-b7ea-d665300fd6c6-0', tool_calls=[{'name': 'search_hotels', 'args': {'city': 'Paris'}, 'id': 'dd4395a1-4541-4cb7-ba0b-66c42fd03da5', 'type': 'tool_call'}], usage_metadata={'input_tokens': 47, 'output_tokens': 104, 'total_tokens': 151, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 89}}), ToolMessage(content='Found hotels in Paris\n    1. Grand Hotel - 5 star, $350/night, spa, pool, gym', name='search_hotels', id='0a8cea1b-4635-4769-b996-ff7d2313fdc8', tool_call_id='dd4395a1-4541-4cb7-ba0b-66c42fd03da5'), AIMessage(content='I found several hotels in Paris, including the Grand Hotel, which is a 5-star hotel, costs $350/night, and has a spa, pool, and gym.', additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019b59f4-4f44-7561-8b13-96dc7a81e7bd-0', usage_metadata={'input_tokens': 104, 'output_tokens': 39, 'total_tokens': 143, 'input_token_details': {'cache_read': 0}}), HumanMessage(content='Find hotels in London', additional_kwargs={}, response_metadata={}, id='63d1b57b-5526-4a1f-b8dd-3e6c1e773107'), AIMessage(content='', additional_kwargs={'function_call': {'name': 'search_hotels', 'arguments': '{"city": "London"}'}, '__gemini_function_call_thought_signatures__': {'de9a88dc-dedb-4b38-a16a-17f673a53126': ''}}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019b59f4-5536-70b0-a22f-64fda11c83ea-0', tool_calls=[{'name': 'search_hotels', 'args': {'city': 'London'}, 'id': 'de9a88dc-dedb-4b38-a16a-17f673a53126', 'type': 'tool_call'}], usage_metadata={'input_tokens': 149, 'output_tokens': 57, 'total_tokens': 206, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 42}}), ToolMessage(content='Found hotels in London\n    1. Grand Hotel - 5 star, $350/night, spa, pool, gym', name='search_hotels', id='93ee53c5-bd9b-4917-a112-671c6dcd106c', tool_call_id='de9a88dc-dedb-4b38-a16a-17f673a53126'), AIMessage(content='I found several hotels in London, including the Grand Hotel, which is a 5-star hotel, costs $350/night, and has a spa, pool, and gym.', additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019b59f4-5c66-7410-9604-f2f737345893-0', usage_metadata={'input_tokens': 206, 'output_tokens': 39, 'total_tokens': 245, 'input_token_details': {'cache_read': 0}}), HumanMessage(content='Find hotels in New York', additional_kwargs={}, response_metadata={}, id='456995ec-2019-4c65-b293-1e74ea03f9ec'), AIMessage(content='', additional_kwargs={'function_call': {'name': 'search_hotels', 'arguments': '{"city": "New York"}'}, '__gemini_function_call_thought_signatures__': {'120da519-7966-4c73-8f56-28b6eea406d8': 'CrUBAXLI2nyyg2WUjZIVx69DWsSi8nBSOsUZsqw9DJLQ92EomRtgQ0MAD7lm0DVfIvFxNIrOVT3UoX1Qo1wVGIRdFc+SM5NOCCoWLnJ6vTG2OfnMezIwGnEhzsUpJkgN4TEM9npesOkF6S5EDYYfIRukIOj7yAYzjthIF0eJ18IAA7v6zPbx2qAVrbApSzEMGIqku1P5L28etaK3hbabRvI8Mr3ocuBPk1uneZkW/QrRV49dGvGeRA=='}}, response_metadata={'fin ...
# ---------------------------------------------------------------------------
# ClientError                               Traceback (most recent call last)
# File d:\Generative AI\langchainupdated\.venv\Lib\site-packages\langchain_google_genai\chat_models.py:3040, in ChatGoogleGenerativeAI._generate(self, messages, stop, run_manager, tools, functions, safety_settings, tool_config, generation_config, cached_content, tool_choice, **kwargs)
#    3039 try:
# -> 3040     response: GenerateContentResponse = self.client.models.generate_content(
#    3041         **request,
#    3042     )
#    3043 except ClientError as e:
#
# File d:\Generative AI\langchainupdated\.venv\Lib\site-packages\google\genai\models.py:5188, in Models.generate_content(self, model, contents, config)
#    5181     logger.warning(
#    5182         'Tools at indices [%s] are not compatible with automatic function '
#    5183         'calling (AFC). AFC is disabled. If AFC is intended, please '
#    (...)   5186         indices_str,
#    5187     )
# -> 5188   return self._generate_content(
#    5189       model=model, contents=contents, config=parsed_config
#    5190   )
#    5192 remaining_remote_calls_afc = _extra_utils.get_max_remote_calls_afc(
#    5193     parsed_config
#    5194 )
#
# File d:\Generative AI\langchainupdated\.venv\Lib\site-packages\google\genai\models.py:3985, in Models._generate_content(self, model, contents, config)
#    3983 request_dict = _common.encode_unserializable_types(request_dict)
# -> 3985 response = self._api_client.request(
#    3986     'post', path, request_dict, http_options
#    3987 )
#    3989 if config is not None and getattr(
#    3990     config, 'should_return_http_response', None
#    3991 ):
#
# File d:\Generative AI\langchainupdated\.venv\Lib\site-packages\google\genai\_api_client.py:1388, in BaseApiClient.request(self, http_method, path, request_dict, http_options)
#    1385 http_request = self._build_request(
#    1386     http_method, path, request_dict, http_options
#    1387 )
# -> 1388 response = self._request(http_request, http_options, stream=False)
#    1389 response_body = (
#    1390     response.response_stream[0] if response.response_stream else ''
#    1391 )
#
# File d:\Generative AI\langchainupdated\.venv\Lib\site-packages\google\genai\_api_client.py:1222, in BaseApiClient._request(self, http_request, http_options, stream)
#    1221     retry = tenacity.Retrying(**retry_kwargs)
# -> 1222     return retry(self._request_once, http_request, stream)  # type: ignore[no-any-return]
#    1224 return self._retry(self._request_once, http_request, stream)
#
# File d:\Generative AI\langchainupdated\.venv\Lib\site-packages\tenacity\__init__.py:477, in Retrying.__call__(self, fn, *args, **kwargs)
#     476 while True:
# --> 477     do = self.iter(retry_state=retry_state)
#     478     if isinstance(do, DoAttempt):
#
# File d:\Generative AI\langchainupdated\.venv\Lib\site-packages\tenacity\__init__.py:378, in BaseRetrying.iter(self, retry_state)
#     377 for action in self.iter_state.actions:
# --> 378     result = action(retry_state)
#     379 return result
#
# File d:\Generative AI\langchainupdated\.venv\Lib\site-packages\tenacity\__init__.py:420, in BaseRetrying._post_stop_check_actions.<locals>.exc_check(rs)
#     419 if self.reraise:
# --> 420     raise retry_exc.reraise()
#     421 raise retry_exc from fut.exception()
#
# File d:\Generative AI\langchainupdated\.venv\Lib\site-packages\tenacity\__init__.py:187, in RetryError.reraise(self)
#     186 if self.last_attempt.failed:
# --> 187     raise self.last_attempt.result()
#     188 raise self
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\concurrent\futures\_base.py:449, in Future.result(self, timeout)
#     448 elif self._state == FINISHED:
# --> 449     return self.__get_result()
#     451 self._condition.wait(timeout)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\concurrent\futures\_base.py:401, in Future.__get_result(self)
#     400 try:
# --> 401     raise self._exception
#     402 finally:
#     403     # Break a reference cycle with the exception in self._exception
#
# File d:\Generative AI\langchainupdated\.venv\Lib\site-packages\tenacity\__init__.py:480, in Retrying.__call__(self, fn, *args, **kwargs)
#     479 try:
# --> 480     result = fn(*args, **kwargs)
#     481 except BaseException:  # noqa: B902
#
# File d:\Generative AI\langchainupdated\.venv\Lib\site-packages\google\genai\_api_client.py:1201, in BaseApiClient._request_once(self, http_request, stream)
#    1194 response = self._httpx_client.request(
#    1195     method=http_request.method,
#    1196     url=http_request.url,
#    (...)   1199     timeout=http_request.timeout,
#    1200 )
# -> 1201 errors.APIError.raise_for_response(response)
#    1202 return HttpResponse(
#    1203     response.headers, response if stream else [response.text]
#    1204 )
#
# File d:\Generative AI\langchainupdated\.venv\Lib\site-packages\google\genai\errors.py:121, in APIError.raise_for_response(cls, response)
#     119   response_json = response.body_segments[0].get('error', {})
# --> 121 cls.raise_error(response.status_code, response_json, response)
#
# File d:\Generative AI\langchainupdated\.venv\Lib\site-packages\google\genai\errors.py:146, in APIError.raise_error(cls, status_code, response_json, response)
#     145 if 400 <= status_code < 500:
# --> 146   raise ClientError(status_code, response_json, response)
#     147 elif 500 <= status_code < 600:
#
# ClientError: 429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/usage?tab=rate-limit. \n* Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 5, model: gemini-2.5-flash\nPlease retry in 9.614098124s.', 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Learn more about Gemini API quotas', 'url': 'https://ai.google.dev/gemini-api/docs/rate-limits'}]}, {'@type': 'type.googleapis.com/google.rpc.QuotaFailure', 'violations': [{'quotaMetric': 'generativelanguage.googleapis.com/generate_content_free_tier_requests', 'quotaId': 'GenerateRequestsPerMinutePerProjectPerModel-FreeTier', 'quotaDimensions': {'location': 'global', 'model': 'gemini-2.5-flash'}, 'quotaValue': '5'}]}, {'@type': 'type.googleapis.com/google.rpc.RetryInfo', 'retryDelay': '9s'}]}}
#
# The above exception was the direct cause of the following exception:
#
# ChatGoogleGenerativeAIError               Traceback (most recent call last)
# Cell In[2], line 51
#      48 cities = ['Paris',"London", "New York", "Tokyo", "Sydney"]
#      50 for city in cities:
# ---> 51     response = agent.invoke(
#      52         {"messages": [HumanMessage(content=f"Find hotels in {city}")]},
#      53         config=config
#      54     )
#      55     tokens = count_tokens(response['messages'])
#      56     fraction = tokens / 128000
#
# File d:\Generative AI\langchainupdated\.venv\Lib\site-packages\langgraph\pregel\main.py:3068, in Pregel.invoke(self, input, config, context, stream_mode, print_mode, output_keys, interrupt_before, interrupt_after, durability, **kwargs)
#    3065 chunks: list[dict[str, Any] | Any] = []
#    3066 interrupts: list[Interrupt] = []
# -> 3068 for chunk in self.stream(
#    3069     input,
#    3070     config,
#    3071     context=context,
#    3072     stream_mode=["updates", "values"]
#    3073     if stream_mode == "values"
#    3074     else stream_mode,
#    3075     print_mode=print_mode,
#    3076     output_keys=output_keys,
#    3077     interrupt_before=interrupt_before,
#    3078     interrupt_after=interrupt_after,
#    3079     durability=durability,
#    3080     **kwargs,
#    3081 ):
#    3082     if stream_mode == "values":
#    3083         if len(chunk) == 2:
#
# File d:\Generative AI\langchainupdated\.venv\Lib\site-packages\langgraph\pregel\main.py:2643, in Pregel.stream(self, input, config, context, stream_mode, print_mode, output_keys, interrupt_before, interrupt_after, durability, subgraphs, debug, **kwargs)
#    2641 for task in loop.match_cached_writes():
#    2642     loop.output_writes(task.id, task.writes, cached=True)
# -> 2643 for _ in runner.tick(
#    2644     [t for t in loop.tasks.values() if not t.writes],
#    2645     timeout=self.step_timeout,
#    2646     get_waiter=get_waiter,
#    2647     schedule_task=loop.accept_push,
#    2648 ):
#    2649     # emit output
#    2650     yield from _output(
#    2651         stream_mode, print_mode, subgraphs, stream.get, queue.Empty
#    2652     )
#    2653 loop.after_tick()
#
# File d:\Generative AI\langchainupdated\.venv\Lib\site-packages\langgraph\pregel\_runner.py:167, in PregelRunner.tick(self, tasks, reraise, timeout, retry_policy, get_waiter, schedule_task)
#     165 t = tasks[0]
#     166 try:
# --> 167     run_with_retry(
#     168         t,
#     169         retry_policy,
#     170         configurable={
#     171             CONFIG_KEY_CALL: partial(
#     172                 _call,
#     173                 weakref.ref(t),
#     174                 retry_policy=retry_policy,
#     175                 futures=weakref.ref(futures),
#     176                 schedule_task=schedule_task,
#     177                 submit=self.submit,
#     178             ),
#     179         },
#     180     )
#     181     self.commit(t, None)
#     182 except Exception as exc:
#
# File d:\Generative AI\langchainupdated\.venv\Lib\site-packages\langgraph\pregel\_retry.py:42, in run_with_retry(task, retry_policy, configurable)
#      40     task.writes.clear()
#      41     # run the task
# ---> 42     return task.proc.invoke(task.input, config)
#      43 except ParentCommand as exc:
#      44     ns: str = config[CONF][CONFIG_KEY_CHECKPOINT_NS]
#
# File d:\Generative AI\langchainupdated\.venv\Lib\site-packages\langgraph\_internal\_runnable.py:656, in RunnableSeq.invoke(self, input, config, **kwargs)
#     654     # run in context
#     655     with set_config_context(config, run) as context:
# --> 656         input = context.run(step.invoke, input, config, **kwargs)
#     657 else:
#     658     input = step.invoke(input, config)
#
# File d:\Generative AI\langchainupdated\.venv\Lib\site-packages\langgraph\_internal\_runnable.py:400, in RunnableCallable.invoke(self, input, config, **kwargs)
#     398         run_manager.on_chain_end(ret)
#     399 else:
# --> 400     ret = self.func(*args, **kwargs)
#     401 if self.recurse and isinstance(ret, Runnable):
#     402     return ret.invoke(input, config)
#
# File d:\Generative AI\langchainupdated\.venv\Lib\site-packages\langchain\agents\factory.py:1131, in create_agent.<locals>.model_node(state, runtime)
#    1118 request = ModelRequest(
#    1119     model=model,
#    1120     tools=default_tools,
#    (...)   1126     runtime=runtime,
#    1127 )
#    1129 if wrap_model_call_handler is None:
#    1130     # No handlers - execute directly
# -> 1131     response = _execute_model_sync(request)
#    1132 else:
#    1133     # Call composed handler with base handler
#    1134     response = wrap_model_call_handler(request, _execute_model_sync)
#
# File d:\Generative AI\langchainupdated\.venv\Lib\site-packages\langchain\agents\factory.py:1102, in create_agent.<locals>._execute_model_sync(request)
#    1099 if request.system_message:
#    1100     messages = [request.system_message, *messages]
# -> 1102 output = model_.invoke(messages)
#    1103 if name:
#    1104     output.name = name
#
# File d:\Generative AI\langchainupdated\.venv\Lib\site-packages\langchain_core\runnables\base.py:5557, in RunnableBindingBase.invoke(self, input, config, **kwargs)
#    5550 @override
#    5551 def invoke(
#    5552     self,
#    (...)   5555     **kwargs: Any | None,
#    5556 ) -> Output:
# -> 5557     return self.bound.invoke(
#    5558         input,
#    5559         self._merge_configs(config),
#    5560         **{**self.kwargs, **kwargs},
#    5561     )
#
# File d:\Generative AI\langchainupdated\.venv\Lib\site-packages\langchain_google_genai\chat_models.py:2529, in ChatGoogleGenerativeAI.invoke(self, input, config, code_execution, stop, **kwargs)
#    2526         msg = "Tools are already defined.code_execution tool can't be defined"
#    2527         raise ValueError(msg)
# -> 2529 return super().invoke(input, config, stop=stop, **kwargs)
#
# File d:\Generative AI\langchainupdated\.venv\Lib\site-packages\langchain_core\language_models\chat_models.py:398, in BaseChatModel.invoke(self, input, config, stop, **kwargs)
#     384 @override
#     385 def invoke(
#     386     self,
#    (...)    391     **kwargs: Any,
#     392 ) -> AIMessage:
#     393     config = ensure_config(config)
#     394     return cast(
#     395         "AIMessage",
#     396         cast(
#     397             "ChatGeneration",
# --> 398             self.generate_prompt(
#     399                 [self._convert_input(input)],
#     400                 stop=stop,
#     401                 callbacks=config.get("callbacks"),
#     402                 tags=config.get("tags"),
#     403                 metadata=config.get("metadata"),
#     404                 run_name=config.get("run_name"),
#     405                 run_id=config.pop("run_id", None),
#     406                 **kwargs,
#     407             ).generations[0][0],
#     408         ).message,
#     409     )
#
# File d:\Generative AI\langchainupdated\.venv\Lib\site-packages\langchain_core\language_models\chat_models.py:1117, in BaseChatModel.generate_prompt(self, prompts, stop, callbacks, **kwargs)
#    1108 @override
#    1109 def generate_prompt(
#    1110     self,
#    (...)   1114     **kwargs: Any,
#    1115 ) -> LLMResult:
#    1116     prompt_messages = [p.to_messages() for p in prompts]
# -> 1117     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#
# File d:\Generative AI\langchainupdated\.venv\Lib\site-packages\langchain_core\language_models\chat_models.py:927, in BaseChatModel.generate(self, messages, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#     924 for i, m in enumerate(input_messages):
#     925     try:
#     926         results.append(
# --> 927             self._generate_with_cache(
#     928                 m,
#     929                 stop=stop,
#     930                 run_manager=run_managers[i] if run_managers else None,
#     931                 **kwargs,
#     932             )
#     933         )
#     934     except BaseException as e:
#     935         if run_managers:
#
# File d:\Generative AI\langchainupdated\.venv\Lib\site-packages\langchain_core\language_models\chat_models.py:1221, in BaseChatModel._generate_with_cache(self, messages, stop, run_manager, **kwargs)
#    1219     result = generate_from_stream(iter(chunks))
#    1220 elif inspect.signature(self._generate).parameters.get("run_manager"):
# -> 1221     result = self._generate(
#    1222         messages, stop=stop, run_manager=run_manager, **kwargs
#    1223     )
#    1224 else:
#    1225     result = self._generate(messages, stop=stop, **kwargs)
#
# File d:\Generative AI\langchainupdated\.venv\Lib\site-packages\langchain_google_genai\chat_models.py:3044, in ChatGoogleGenerativeAI._generate(self, messages, stop, run_manager, tools, functions, safety_settings, tool_config, generation_config, cached_content, tool_choice, **kwargs)
#    3040     response: GenerateContentResponse = self.client.models.generate_content(
#    3041         **request,
#    3042     )
#    3043 except ClientError as e:
# -> 3044     _handle_client_error(e, request)
#    3046 return _response_to_result(response)
#
# File d:\Generative AI\langchainupdated\.venv\Lib\site-packages\langchain_google_genai\chat_models.py:145, in _handle_client_error(e, request)
#     143 model_name = request.get("model", "unknown")
#     144 msg = f"Error calling model '{model_name}' ({e.status}): {e}"
# --> 145 raise ChatGoogleGenerativeAIError(msg) from e
#
# ChatGoogleGenerativeAIError: Error calling model 'gemini-2.5-flash' (RESOURCE_EXHAUSTED): 429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/usage?tab=rate-limit. \n* Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 5, model: gemini-2.5-flash\nPlease retry in 9.614098124s.', 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Learn more about Gemini API quotas', 'url': 'https://ai.google.dev/gemini-api/docs/rate-limits'}]}, {'@type': 'type.googleapis.com/google.rpc.QuotaFailure', 'violations': [{'quotaMetric': 'generativelanguage.googleapis.com/generate_content_free_tier_requests', 'quotaId': 'GenerateRequestsPerMinutePerProjectPerModel-FreeTier', 'quotaDimensions': {'location': 'global', 'model': 'gemini-2.5-flash'}, 'quotaValue': '5'}]}, {'@type': 'type.googleapis.com/google.rpc.RetryInfo', 'retryDelay': '9s'}]}}
# During task with name 'model' and id 'e06ed1e8-a610-71e7-3435-99261274576d'

# %% [markdown]
# ### Human in the Loop MiddleWare

# %% [markdown]
# Pause agent execution for human approval, editing or rejection of tool calls before they execute. Human-in-the-loop (HITL) is useful for the following:
#
# - High-Stakes operations requiring human approval(e.g. database writes, financial transactions)
# - Compilance workflows where human overesight is mandotary.
# - Long running conversations where human feedback guides the agent.

# %%
from langchain.agents import create_agent
from langchain.agents.middleware import HumanInTheLoopMiddleware
from langgraph.checkpoint.memory import InMemorySaver

def read_email_tool(email_id: str) -> str:
    """Mock function to read an email by its ID"""
    return f"Email content for ID: {email_id}"

def send_email_tool(recipient: str, subject: str, body: str) -> str:
    """Mock function to send an email"""
    return f"Email sent to{recipient} with subject: '{subject}'"

# %%
agent = create_agent(
    model=llm,
    tools=[read_email_tool, send_email_tool],
    checkpointer=InMemorySaver(),
    middleware=[
        HumanInTheLoopMiddleware(
            interrupt_on={
                "send_email_tool":{
                    "allowed_decision":["approve","edit","reject"]
                },
                "read_email_tool":False,
            }
        )
    ],
)

# %%
config = {"configurable": {"thread_id": "test-approve"}}

result = agent.invoke(
    {"messages": [HumanMessage(content="send email to john@test.com with subject 'Hello' and body 'How are you?'")]},
    config=config
)

# %%
result

# %%
from langgraph.types import Command
if "__interrupt__" in result:
    print("Paused Approval!!...")

    result = agent.invoke(
        command(
            resume={
                "decision": {
                    {"type":"approve"}
                }
            }
        ),
        config = config
    ) 
    
    print(f"Result: {result['messages'][-1].content}")

# %%
from langgraph.types import Command
if "__interrupt__" in result:
    print("Paused Approval!!...")

    result = agent.invoke(
        command(
            resume={
                "decision": {
                    {"type":"reject"}
                }
            }
        ),
        config = config
    ) 
    
    print(f"Result: {result['messages'][-1].content}")
